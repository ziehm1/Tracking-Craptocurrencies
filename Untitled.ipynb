# %% [markdown]
# # Jupyter Data Science Workflow

# %%
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline

import glob

# %%
URL = 'https://data.seattle.gov/api/views/mdbt-9ykn/rows.csv?accessType=DOWNLOAD'

# %%
from urllib.request import urlretrieve
urlretrieve(URL, 'Fremont.csv')
# Out:
# ('Fremont.csv', <http.client.HTTPMessage at 0x18e3444f240>)

# %%
data = pd.read_csv('Fremont.csv', index_col='Date',parse_dates=True)
data.head()
# Out:
#             Fremont Bridge West Sidewalk  Fremont Bridge East Sidewalk
# Date
# 2014-12-01                         23689                         24818
# 2012-11-01                         26062                         24585
# 2012-12-01                         18608                         17761
# 2015-01-01                         35754                         24876
# 2017-07-01                         50973                         67931

# %%
data.plot()

# %%
plt.style.use('ggplot')
data.plot()

# %%
print(matplotlib.get_configdir())
# Out:
# C:\Users\Ziehm1\.matplotlib

# %%
plt.style.available
# Out:
# ['seaborn-muted',
#  'dark_background',
#  'ggplot',
#  'seaborn-whitegrid',
#  'fivethirtyeight',
#  'grayscale',
#  'seaborn-notebook',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-poster',
#  'bmh',
#  'seaborn-talk',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'classic',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-ticks',
#  'seaborn-white']

# %%
for i in range(0,20):
    plt.style.use(plt.style.available[i])
    data.plot()

# %%
plt.style.use('classic')
data.plot()

# %%
data.columns = ['West','East']

# %%
data.plot()

# %%
# Out:
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:2782: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   'left=%s, right=%s') % (left, right))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     225
#     226     if 'png' in formats:
# --> 227         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     228     if 'retina' in formats or 'png2x' in formats:
#     229         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     117
#     118     bytes_io = BytesIO()
# --> 119     fig.canvas.print_figure(bytes_io, **kw)
#     120     data = bytes_io.getvalue()
#     121     if fmt == 'svg':
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2178                     orientation=orientation,
#    2179                     dryrun=True,
# -> 2180                     **kwargs)
#    2181                 renderer = self.figure._cachedRenderer
#    2182                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     525
#     526     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 527         FigureCanvasAgg.draw(self)
#     528         renderer = self.get_renderer()
#     529         original_dpi = renderer.dpi
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2317
#    2318         for zorder, a in dsu:
# -> 2319             a.draw(renderer)
#    2320
#    2321         renderer.close_group('axes')
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1106         renderer.open_group(__name__)
#    1107
# -> 1108         ticks_to_draw = self._update_ticks(renderer)
#    1109         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1110                                                                 renderer)
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self, renderer)
#     949
#     950         interval = self.get_view_interval()
# --> 951         tick_tups = [t for t in self.iter_ticks()]
#     952         if self._smart_bounds:
#     953             # handle inverted limits
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#     949
#     950         interval = self.get_view_interval()
# --> 951         tick_tups = [t for t in self.iter_ticks()]
#     952         if self._smart_bounds:
#     953             # handle inverted limits
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\axis.py in iter_ticks(self)
#     896         self.major.formatter.set_locs(majorLocs)
#     897         majorLabels = [self.major.formatter(val, i)
# --> 898                        for i, val in enumerate(majorLocs)]
#     899
#     900         minorLocs = self.minor.locator()
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#     896         self.major.formatter.set_locs(majorLocs)
#     897         majorLabels = [self.major.formatter(val, i)
# --> 898                        for i, val in enumerate(majorLocs)]
#     899
#     900         minorLocs = self.minor.locator()
#
# C:\Users\Ziehm1\Anaconda3\lib\site-packages\pandas\tseries\converter.py in __call__(self, x, pos)
#      98             fmt += '.%3f'
#      99
# --> 100         return pydt.time(h, m, s, us).strftime(fmt)
#     101
#     102
#
# ValueError: microsecond must be in 0..999999
